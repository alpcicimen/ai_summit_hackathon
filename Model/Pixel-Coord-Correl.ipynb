# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
data = Image.open("GBR_wind-speed_50m.tif")

# %%
data.show()

# %%
data_np = np.array(data)

# %%
data_mod = np.where(np.isnan(data_np) == 0, 1, 0)

# %%
plt.imshow(data_mod)

# %% [markdown]
# 54.68, -7.84 -> 3675, 2810
# 54.3, -7.87 -> 3840, 2800
#
# Lat degree diff corresp to 434 pixels
# Long degree diff corresp to 333 pixels

# %%
plt.imshow(data_mod[3600:4000, 2700:3300])
